# %% [markdown]
# S & P stock list

# %%
from spx_symbols import save_spx_symbols
save_spx_symbols()
# Out:
# Saving complete for spx_stocks

# %% [markdown]
# Company Info

# %%
from data_finnhub import save_spx_stock_profile
save_spx_stock_profile()
# Out:
# 1: MMM
# 2: AOS
# 3: ABT
# 4: ABBV
# 5: ACN
# 6: ADBE
# 7: AMD
# 8: AES
# 9: AFL
# 10: A
# 11: APD
# 12: ABNB
# 13: AKAM
# 14: ALB
# 15: ARE
# 16: ALGN
# 17: ALLE
# 18: LNT
# 19: ALL
# 20: GOOGL
# 21: MO
# 22: AMZN
# 23: AMCR
# 24: AEE
# 25: AEP
# 26: AXP
# 27: AIG
# 28: AMT
# 29: AWK
# 30: AMP
# 31: AME
# 32: AMGN
# 33: APH
# 34: ADI
# 35: AON
# 36: APA
# 37: APO
# 38: AAPL
# 39: AMAT
# 40: APP
# 41: APTV
# 42: ACGL
# 43: ADM
# 44: ARES
# 45: ANET
# 46: AJG
# 47: AIZ
# 48: T
# 49: ATO
# 50: ADSK
# 51: ADP
# 52: AZO
# 53: AVB
# 54: AVY
# 55: AXON
# 56: BKR
# 57: BALL
# 58: BAC
# 59: BAX
# 60: BDX
# 61: BRK-B
# 62: BBY
# 63: TECH
# 64: BIIB
# 65: BLK
# 66: BX
# 67: XYZ
# 68: BNY
# 69: BA
# 70: BKNG
# 71: BSX
# 72: BMY
# 73: AVGO
# 74: BR
# 75: BRO
# 76: BF-B
# 77: BLDR
# 78: BG
# 79: BXP
# 80: CHRW
# 81: CDNS
# 82: CPT
# 83: CPB
# 84: COF
# 85: CAH
# 86: CCL
# 87: CARR
# 88: CVNA
# 89: CASY
# 90: CAT
# 91: CBOE
# 92: CBRE
# 93: CDW
# 94: COR
# 95: CNC
# 96: CNP
# 97: CF
# 98: CRL
# ...

# %% [markdown]
# Candlestick Chart

# %%
from data_yfinance import save_spx_yfin_chart_data
save_spx_yfin_chart_data(period="5y")
# Out:
# Saving complete for spx_chart
# All stocks are saved successfully

# %% [markdown]
# Stock Market Capitalization table

# %%
from data_yfinance import save_yfin_market_cap
save_yfin_market_cap()
# Out:
# Saving complete for spx_market_cap
# All stocks are saved successfully

# %% [markdown]
# Stock Growth table

# %%
from spx_heatmap import save_growth_table
save_growth_table()
# Out:
# Saving complete for database table spx_growth

# %% [markdown]
# Heatmap table

# %%
from spx_heatmap import save_heatmap_table
save_heatmap_table()
# Out:
# Saving complete for database table spx_heatmap
